# %% [markdown]
# # Data extracation and understading

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Genet Shanko\A_startUp\A_Startup_Data-_Warehouse-\Dataset\Data_fromD5_20181029_d5_0800_0830.csv",sep='[,;:]',index_col=False)
#df = pd.read_csv("extracted.csv")

df.head()
# Out:
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_4524\492409508.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(r"C:\Users\Genet Shanko\A_startUp\A_Startup_Data-_Warehouse-\Dataset\Data_fromD5_20181029_d5_0800_0830.csv",sep='[,;:]',index_col=False)
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_4524\492409508.py:2: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(r"C:\Users\Genet Shanko\A_startUp\A_Startup_Data-_Warehouse-\Dataset\Data_fromD5_20181029_d5_0800_0830.csv",sep='[,;:]',index_col=False)
#    track_id         type   traveled_d   avg_speed        lat        lon  \
# 0         1          Car       301.84   26.763856  37.983325  23.730301
# ...

# %%
df.rename(columns = {' type':'cars'}, inplace=True)

# %%
df
# Out:
#       track_id             cars   traveled_d   avg_speed        lat  \
# 0            1              Car       301.84   26.763856  37.983325
# 1            2              Car       233.84   11.437842  37.984839
# 2            3              Car       220.23   11.135303  37.984721
# 3            4       Motorcycle       193.41   10.454371  37.984477
# 4            5              Car       258.96   10.967531  37.984273
# ...        ...              ...          ...         ...        ...
# 2051      2052              Car        10.40   23.397068  37.983794
# 2052      2053             Taxi         7.45   22.357054  37.985772
# 2053      2054   Medium Vehicle         6.16   36.972973  37.983163
# 2054      2055              Car         3.66   21.979008  37.983806
# 2055      2056              Car         2.55   22.989076  37.983767
#
#             lon    speed   lon_acc   lat_acc   time
# 0     23.730301  56.7541    0.1710   -0.0346    0.0
# ...
