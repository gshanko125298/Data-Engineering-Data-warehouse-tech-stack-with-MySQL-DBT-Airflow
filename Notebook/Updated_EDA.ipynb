# %% [markdown]
# # Exploratory Data Analysis

# %%
import sys
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sys.path.append("../scr/")

# %%
from load_file import DataReader

# %% [markdown]
# # loading Data

# %%
#columns
reader = DataReader(file_path="../data/20181024_d1_0830_0900.csv")
vehicle_df, trajectories_df = reader.get_dfs(v=1)

# %%
data = pd.read_csv(r"F:\Dataset\DATA_20181030_d10_0830_0900 (1).csv", sep="[,;:]", index_col=False)
data.head()
# Out:
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_15388\1149871507.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(r"F:\Dataset\DATA_20181030_d10_0830_0900 (1).csv", sep="[,;:]", index_col=False)
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_15388\1149871507.py:1: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   data = pd.read_csv(r"F:\Dataset\DATA_20181030_d10_0830_0900 (1).csv", sep="[,;:]", index_col=False)
#    track_id         type   traveled_d   avg_speed        lat        lon  \
# 0         1   Motorcycle       400.16   29.279898  37.983925  23.728950
# 1         2         Taxi        19.03    7.135194  37.984488  23.725652
# ...

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=data, x=" type")
plt.title(f'Distribution of Car type', size=18, fontweight='bold')
plt.show()

# %%
data.info
# Out:
# <bound method DataFrame.info of       track_id             type   traveled_d   avg_speed        lat  \
# 0            1       Motorcycle       400.16   29.279898  37.983925
# 1            2             Taxi        19.03    7.135194  37.984488
# 2            3             Taxi        77.69   19.977136  37.984521
# 3            4              Car       429.87    3.838099  37.983845
# 4            5             Taxi       201.66   28.808789  37.984272
# ...        ...              ...          ...         ...        ...
# 2454      2455   Medium Vehicle        13.26   29.830820  37.983242
# 2455      2456       Motorcycle         8.80   31.662041  37.984869
# 2456      2457              Car         5.70   20.530227  37.983731
# 2457      2458       Motorcycle         5.20   23.398418  37.983701
# 2458      2459       Motorcycle         1.31   23.552073  37.983751
#
#             lon    speed   lon_acc   lat_acc   time
# 0     23.728950  25.6984    0.1504    0.0447    0.0
# ...

# %%
data.isnull().sum()
# Out:
# track_id       0
#  type          0
#  traveled_d    0
#  avg_speed     0
#  lat           0
#  lon           0
#  speed         0
#  lon_acc       0
#  lat_acc       0
#  time          0
# dtype: int64

# %%
data.dtypes
# Out:
# track_id         int64
#  type           object
#  traveled_d    float64
#  avg_speed     float64
#  lat           float64
#  lon           float64
#  speed         float64
#  lon_acc       float64
#  lat_acc       float64
#  time          float64
# dtype: object

# %%
sns.displot(data=data, x=" avg_speed", color="green", kde=True, height=8, aspect=2)
plt.title(f'Distribution of speed', size=20, fontweight='bold')
plt.show()

# %%
sns.displot(data=data, x=" time", color="red", kde=True, height=8, aspect=2)
plt.title(f'Distribution of time', size=20, fontweight='bold')
plt.show()
